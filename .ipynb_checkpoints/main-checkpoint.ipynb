# %% [markdown]
# # Detection of Malicicous Data

# %% [markdown]
# ## Part I: Preprocessing

# %% [markdown]
# ### Read the data.file
# The data file includes dataset structured like Basic Safety Messages (BSM) defined in the SEA J2735 standard, including vehicle's location, speed, acceleration, heading, and brake status. We utilize the data to check the correcteness of the data and better classify the five types of position spoofing attack.

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

# %%
cols = [2,3,4,9,10,16] #id, xr ,yr, xt,yt, label
data = pd.read_csv("dataset/attack1withlabels.csv",usecols=cols)
data = data.dropna(axis=0, how="any")#remove invalid data
data_id = data.iloc[:,0]
# attack 1: distance is too far recevier and transmitter
pos_xr = data.iloc[:,1]
pos_yr = data.iloc[:,2]
pos_xt = data.iloc[:,3]
pos_yt = data.iloc[:,4]

label = data.iloc[:,5]

# %% [markdown]
# ### colunm data
# 1. Type (3=BSM)
# 2. Time BSM was received by the receiver
# 3. Receiver ID
# 4. Receiver X position
# 5. Receiver Y position
# 6. Receiver Z position
# 7. Time BSM was transmitted
# 8. Transmitter ID
# 9. BSM ID
# 10. Transmitter X position
# 11. Transmitter Y position
# 12. Transmitter Z position
# 13. Transmitter X velocity
# 14. Transmitter Y velocity
# 15. Transmitter Z velocity
# 16. RSSI (Received Signal Strength Indicator)
# 17. Label (0=Normal Behavior)

# %%
# calculate distance between 2 point 
def cal_dis(x1,y1,x2,y2):
    return np.sqrt( np.square(x1-x2)+np.square(y1-y2))

# %% [markdown]
# ## impletation keras

# %%
from tensorflow.python.keras import backend as k
from keras.models import Sequential
from keras.layers import Dense,Activation
from keras.layers.recurrent import LSTM
import tensorflow
from sklearn import model_selection

# %%
# model implementation
model = Sequential()
# model.add(LSTM(32, input_shape=(None,5),return_sequences=False))
model.add(Dense(1,input_dim=5))
model.add(Dense(1,activation="sigmoid"))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# We read the data from the data.
cols = [2,3,4,9,10,15,16] #id, xr ,yr, xt, yt, RSSI, label.
data = pd.read_csv("dataset/attack1withlabels.csv", usecols=cols, header=None)
X = data.iloc[:,:6]
y = data.iloc[:,6]

# %% [markdown]
# Two observations for attack 1
# * The fake distance exceed the upper bound of communication range which is 800m
# * The distance does not change but the RSSI changes.
# The first criteria is trivial, thus we apply a filter.

# %%
len(y)
# Out:
# 425708

# %%
def dis_over_comm_range(X, y, thredhold):
    out_range=np.zeros(len(y))
    for i in range(len(y)):
        if np.linalg.norm([X.iloc[i][3]-X.iloc[i][9], X.iloc[i][4]-X.iloc[i][10]])<thredhold:
            out_range[i] = 1
            
    index_out_range = np.where(out_range==1)  
    x_filter = X.drop(index_out_range,axis=0)
    y_filter = y.drop(index_out_range,axis=0)
    return x_filter, y_filter

x_filter, y_filter = dis_over_comm_range(X, y, 800)

# %% [markdown]
# After pre-processing, we get the following relevant information:
# 1. The ID of the transmitter BSM
# 2. Transmitter positions
# 3. The distance between transmitter and receiver
# 4. The RSSI
# We feed the following information into the training model.

# %%
data_count = y_filter.count()
data_rate = 0.8 * data_count
data_rate = int(data_rate)

X_train = x_filter.iloc[:data_rate,:]
y_train = y_filter.iloc[:data_rate]
X_test = x_filter.iloc[data_rate:,:]
y_test = y_filter.iloc[data_rate:]

X_train.shape
# Out:
# (319280, 5)

# %%
#fit data
model.fit(X_train.values,y_train.values,epochs=100,batch_size=100)
# Out:
# Epoch 1/100
# 319280/319280 [==============================] - 4s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 2/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 3/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 4/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 5/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 6/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 7/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 8/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 9/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 10/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 11/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 12/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 13/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 14/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 15/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 16/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 17/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 18/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 19/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 20/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 21/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 22/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 23/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 24/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 25/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 26/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 27/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 28/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 29/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 30/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 31/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 32/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 33/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 34/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 35/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 36/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 37/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 38/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 39/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 40/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 41/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 42/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 43/100
# 319280/319280 [==============================] - 4s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 44/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 45/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 46/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 47/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 48/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 49/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 50/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 51/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 52/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 53/100
# 319280/319280 [==============================] - 5s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 54/100
# 319280/319280 [==============================] - 5s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 55/100
# 319280/319280 [==============================] - 4s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 56/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 57/100
# 319280/319280 [==============================] - 4s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 58/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 59/100
# 319280/319280 [==============================] - 4s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 60/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758: 1s
# Epoch 61/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 62/100
# 319280/319280 [==============================] - 4s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 63/100
# 319280/319280 [==============================] - 4s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 64/100
# 319280/319280 [==============================] - 5s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 65/100
# 319280/319280 [==============================] - 5s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 66/100
# 319280/319280 [==============================] - 4s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 67/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 68/100
# 319280/319280 [==============================] - 4s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 69/100
# 319280/319280 [==============================] - 4s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 70/100
# 319280/319280 [==============================] - 5s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 71/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 72/100
# 319280/319280 [==============================] - 4s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 73/100
# 319280/319280 [==============================] - 5s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 74/100
# 319280/319280 [==============================] - 5s 15us/step - loss: 5.2262 - acc: 0.6758
# Epoch 75/100
# 319280/319280 [==============================] - 5s 15us/step - loss: 5.2262 - acc: 0.6758
# Epoch 76/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 77/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 78/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 79/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 80/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 81/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 82/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 83/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 84/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 85/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 86/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 87/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 88/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 89/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 90/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 91/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 92/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 93/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 94/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 95/100
# 319280/319280 [==============================] - 4s 14us/step - loss: 5.2262 - acc: 0.6758
# Epoch 96/100
# 319280/319280 [==============================] - 4s 13us/step - loss: 5.2262 - acc: 0.6758
# Epoch 97/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 98/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 99/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758
# Epoch 100/100
# 319280/319280 [==============================] - 4s 12us/step - loss: 5.2262 - acc: 0.6758

# %%
cost = model.evaluate(X_test.values,y_test.values,batch_size=100)
print('loss \n',cost[0])
print('accurency \n',cost[1])
# Out:
# 106427/106427 [==============================] - 1s 7us/step
# loss
#  5.063493408206234
# accurency
#  0.6858503946080587

# %%
X_train
# Out:
#          562  5607.3  5965.1  5367.5  5930.1
# 0        562  5594.2  5973.5  5373.5  5934.6
# 1        562  5583.8  5980.2  5368.1  5924.2
# 2       3166  3642.0  5183.0  5560.0  5820.0
# 3       3166  3642.0  5183.0  3781.6  5256.0
# 4       3166  3642.0  5183.0  5560.0  5820.0
# 5       3166  3642.0  5183.0  4168.2  5286.1
# 6       3166  3642.0  5183.0  3609.1  5420.4
# 7       3166  3641.4  5186.5  3485.7  5192.2
